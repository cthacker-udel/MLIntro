# %%
import pandas as pd
import numpy as np

# %%
players_df = pd.read_csv('all_seasons.csv', index_col=0, encoding="ISO-8859-1")
player_info_df = pd.read_csv('NBA_Player_IDs.csv', encoding="ISO-8859-1")

player_info_df['player_name'] = player_info_df['NBAName']

merged_df = pd.merge(players_df, player_info_df, on='player_name')

merged_df = merged_df.drop(
    columns=[
        "ESPNLink",
        "ESPNName",
        "ESPNID",
        "ESPNBirthDate",
        "SpotracID",
        "SpotracName",
        "SpotracLink",
        "ESPNBirthDate",
    ]
)

merged_df.fillna(0, inplace=True)

merged_df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12       99.79024
# 1      Dennis Rodman               CHI  37.0         198.12       99.79024
# 2      Dennis Rodman               LAL  38.0         200.66       95.25432
# 3      Dennis Rodman               DAL  39.0         200.66       95.25432
# 4  Dwayne Schintzius               LAC  28.0         215.90      117.93392
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1  Southeastern Oklahoma State     USA       1986           2           27
# 2  Southeastern Oklahoma State     USA       1986           2           27
# 3  Southeastern Oklahoma State     USA       1986           2           27
# 4                      Florida     USA       1990           1           24
#
#    ...  ast_pct   season          BBRefName  \
# 0  ...    0.113  1996-97      Dennis Rodman
# 1  ...    0.112  1997-98      Dennis Rodman
# 2  ...    0.063  1998-99      Dennis Rodman
# 3  ...    0.046  1999-00      Dennis Rodman
# 4  ...    0.048  1996-97  Dwayne Schintzius
#
#                                            BBRefLink    BBRefID  \
# 0  https://www.basketball-reference.com/players/r...  rodmade01
# 1  https://www.basketball-reference.com/players/r...  rodmade01
# 2  https://www.basketball-reference.com/players/r...  rodmade01
# 3  https://www.basketball-reference.com/players/r...  rodmade01
# 4  https://www.basketball-reference.com/players/s...  schindw01
#
#    BBRefBirthDate            NBAName                            NBALink  \
# 0       5/13/1961      Dennis Rodman   https://stats.nba.com/player/23/
# 1       5/13/1961      Dennis Rodman   https://stats.nba.com/player/23/
# 2       5/13/1961      Dennis Rodman   https://stats.nba.com/player/23/
# 3       5/13/1961      Dennis Rodman   https://stats.nba.com/player/23/
# 4      10/14/1968  Dwayne Schintzius  https://stats.nba.com/player/368/
#
#    NBAID  NBABirthDate
# 0   23.0     5/13/1961
# 1   23.0     5/13/1961
# 2   23.0     5/13/1961
# 3   23.0     5/13/1961
# 4  368.0    10/14/1968
#
# [5 rows x 29 columns]

# %%
try:
    found_player_info = merged_df[merged_df['NBAName'] == 'Dwayne Wade']
except Exception as e:
    print(e)

found_player_info
# Out:
# {'player_name': {0: 'Dennis Rodman', 1: 'Dennis Rodman', 2: 'Dennis Rodman', 3: 'Dennis Rodman'}, 'team_abbreviation': {0: 'CHI', 1: 'CHI', 2: 'LAL', 3: 'DAL'}, 'age': {0: 36.0, 1: 37.0, 2: 38.0, 3: 39.0}, 'player_height': {0: 198.12, 1: 198.12, 2: 200.66, 3: 200.66}, 'player_weight': {0: 99.79024, 1: 99.79024, 2: 95.25432, 3: 95.25432}, 'college': {0: 'Southeastern Oklahoma State', 1: 'Southeastern Oklahoma State', 2: 'Southeastern Oklahoma State', 3: 'Southeastern Oklahoma State'}, 'country': {0: 'USA', 1: 'USA', 2: 'USA', 3: 'USA'}, 'draft_year': {0: '1986', 1: '1986', 2: '1986', 3: '1986'}, 'draft_round': {0: '2', 1: '2', 2: '2', 3: '2'}, 'draft_number': {0: '27', 1: '27', 2: '27', 3: '27'}, 'gp': {0: 55, 1: 80, 2: 23, 3: 12}, 'pts': {0: 5.7, 1: 4.7, 2: 2.1, 3: 2.8}, 'reb': {0: 16.1, 1: 15.0, 2: 11.2, 3: 14.3}, 'ast': {0: 3.1, 1: 2.9, 2: 1.3, 3: 1.2}, 'net_rating': {0: 16.1, 1: 6.7, 2: -1.4, 3: -7.1}, 'oreb_pct': {0: 0.186, 1: 0.1689999999999999, 2: 0.114, 3: 0.136}, 'dreb_pct': {0: 0.3229999999999999, 1: 0.319, 2: 0.348, 3: 0.351}, 'usg_pct': {0: 0.1, 1: 0.088, 2: 0.065, 3: 0.064}, 'ts_pct': {0: 0.479, 1: 0.4589999999999999, 2: 0.3879999999999999, 3: 0.457}, 'ast_pct': {0: 0.113, 1: 0.1119999999999999, 2: 0.063, 3: 0.046}, 'season': {0: '1996-97', 1: '1997-98', 2: '1998-99', 3: '1999-00'}, 'BBRefName': {0: 'Dennis Rodman', 1: 'Dennis Rodman', 2: 'Dennis Rodman', 3: 'Dennis Rodman'}, 'BBRefLink': {0: 'https://www.basketball-reference.com/players/r/rodmade01.html', 1: 'https://www.basketball-reference.com/players/r/rodmade01.html', 2: 'https://www.basketball-reference.com/players/r/rodmade01.html', 3: 'https://www.basketball-reference.com/players/r/rodmade01.html'}, 'BBRefID': {0: 'rodmade01', 1: 'rodmade01', 2: 'rodmade01', 3: 'rodmade01'}, 'BBRefBirthDate': {0: '5/13/1961', 1: '5/13/1961', 2: '5/13/1961', 3: '5/13/1961'}, 'NBAName': {0: 'Dennis Rodman', 1: 'Dennis Rodman', 2: 'Dennis Rodman', 3: 'Dennis Rodman'}, 'NBALink': {0: 'https://stats.nba.com/player/23/', 1: 'https://stats.nba.com/player/23/', 2: 'https://stats.nba.com/player/23/', 3: 'https://stats.nba.com/player/23/'}, 'NBAID': {0: 23.0, 1: 23.0, 2: 23.0, 3: 23.0}, 'NBABirthDate': {0: '5/13/1961', 1: '5/13/1961', 2: '5/13/1961', 3: '5/13/1961'}}
# Empty DataFrame
# Columns: [player_name, team_abbreviation, age, player_height, player_weight, college, country, draft_year, draft_round, draft_number, gp, pts, reb, ast, net_rating, oreb_pct, dreb_pct, usg_pct, ts_pct, ast_pct, season, BBRefName, BBRefLink, BBRefID, BBRefBirthDate, NBAName, NBALink, NBAID, NBABirthDate]
# Index: []
#
# [0 rows x 29 columns]

# %%
merged_df[merged_df['player_name'].str.startswith('Dennis Rodman')]
# Out:
#      player_name team_abbreviation   age  player_height  player_weight  \
# 0  Dennis Rodman               CHI  36.0         198.12       99.79024
# 1  Dennis Rodman               CHI  37.0         198.12       99.79024
# 2  Dennis Rodman               LAL  38.0         200.66       95.25432
# 3  Dennis Rodman               DAL  39.0         200.66       95.25432
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1  Southeastern Oklahoma State     USA       1986           2           27
# 2  Southeastern Oklahoma State     USA       1986           2           27
# 3  Southeastern Oklahoma State     USA       1986           2           27
#
#    ...  ast_pct   season      BBRefName  \
# 0  ...    0.113  1996-97  Dennis Rodman
# 1  ...    0.112  1997-98  Dennis Rodman
# 2  ...    0.063  1998-99  Dennis Rodman
# 3  ...    0.046  1999-00  Dennis Rodman
#
#                                            BBRefLink    BBRefID  \
# 0  https://www.basketball-reference.com/players/r...  rodmade01
# 1  https://www.basketball-reference.com/players/r...  rodmade01
# 2  https://www.basketball-reference.com/players/r...  rodmade01
# 3  https://www.basketball-reference.com/players/r...  rodmade01
#
#    BBRefBirthDate        NBAName                           NBALink  NBAID  \
# 0       5/13/1961  Dennis Rodman  https://stats.nba.com/player/23/   23.0
# 1       5/13/1961  Dennis Rodman  https://stats.nba.com/player/23/   23.0
# 2       5/13/1961  Dennis Rodman  https://stats.nba.com/player/23/   23.0
# 3       5/13/1961  Dennis Rodman  https://stats.nba.com/player/23/   23.0
#
#    NBABirthDate
# 0     5/13/1961
# 1     5/13/1961
# 2     5/13/1961
# 3     5/13/1961
#
# [4 rows x 29 columns]
